# %%
import pprint
from googleapiclient.discovery import build
import sys
import re
from collections import defaultdict
import math

# %%
class Query_result(object):
    def __init__(self, title=None, link=None, snippet=None):
        self.title = title
        self.link = link
        self.summary = snippet
        self.is_relevant = False

# %%
def search(query_terms):
    '''
    Search by calling Google Custom Search API
    with input query terms. 
    Return a list of (10) search results.
    '''
    # Call Google Custom Search API
    service = build("customsearch", "v1", developerKey=JSON_API_KEY)
    query = ' '.join(query_terms)
    res = service.cse().list(q=query, cx=SEARCH_ENGINE_ID,).execute()
    
    # Parse returned query results
    result = []
    for item in res['items']:
        # unicode to utf-8
        title = item['title'].encode('utf-8').strip()
        link = item['link'].encode('utf-8').strip()
        snippet = item['snippet'].encode('utf-8').strip()
        t = Query_result(title, link, snippet)
        result.append(t)
    
    return result

# %%
def get_feedback(query_result, query):
    '''
    Print query results out, 
    Add user's feedback information
    to Query_result.label attribute
    '''
    print "Parameters:"
    print "Client Key = {}\nEngine Key = {}\nQuery = {}\nPrecision = {}".format(JSON_API_KEY, SEARCH_ENGINE_ID, ' '.join(query), PREC)
    print "Google Search Results:"
    print "======================"
    
    # Print each query result
    for i, v in enumerate(query_result):
        print "\nResult #{}:".format(i+1)
        print "["
        print "URL: {}\n".format(v.link)
        print "Title: {}\n".format(v.title)
        print "Summary: {}\n".format(v.summary)
        print "]\n"
        # Receive user's feedback
        feedback = raw_input("Relevant ([Y]/N)?")
        assert(feedback == '' or feedback.lower() in 'yn')
        if feedback == '' or feedback.lower() == 'y':
            v.is_relevant = True

    return

# %%
def modify_query(query_result, query, alpha=0.75, beta=0.15):
    '''
    According to the user's feedback,
    derive new terms for query,
    and adjust order of query terms.
    '''
    N = len(query_result)
    re_vectors, irre_vectors, doc_freq = [], [], defaultdict(set)
    
    # Count term frequency and document frequency for each term in each document
    print "Indexing results ..."
    for i, v in enumerate(query_result):
        vector = defaultdict(int)
        terms = regularize(v.title + ' ' + v.summary) # terms: all terms in a document
        for term in terms:
            doc_freq[term].add(i)
            vector[term] += 1
        if v.is_relevant:
            re_vectors.append(vector)  
        else:
            irre_vectors.append(vector)         
    
    # After this loop, every vector, each representing a document,
    # will store the tf-idf value for each term in this document
    for vector in re_vectors + irre_vectors:
        for term in vector:
            vector[term] = math.log(1+vector[term], 10) * math.log(float(N)/len(doc_freq[term]), 10) * 10000
    
    # Rocchio Algorithm -- combine all relevant and irrelevant vectors
    print "Indexing results ..."
    DR, DNR = len(re_vectors), len(irre_vectors)
    new_vector = defaultdict(float)
    for vector in re_vectors:
        for term in vector:
            new_vector[term] += vector[term] * alpha / DR 
    for vector in irre_vectors:
        for term in vector:
            new_vector[term] = max(0, new_vector[term] - vector[term] * beta / DNR)

    # Print new_vector, for test purposes
    pprint.pprint(sorted([(i, v) for i, v in new_vector.iteritems()], key=lambda x: x[1], reverse=True))
        
    # Find (up to) 2 "new" terms in new_vector and add them to query terms
    first, second, first_val, second_val = '', '', 0, 0
    for term in new_vector:
        if term not in query and new_vector[term] > 0: # pass terms that are already in query terms
            weight = new_vector[term]
            if weight > first_val:
                first, first_val, second, second_val = term, weight, first, first_val
            elif weight > second_val:
                second, second_val = term, weight
            else:
                pass
    
    if first: query.append(first)
    if second: query.append(second)    
    print "Augmenting by {}".format(first + ' ' + second)
    
    # Arrange new order of query terms：
    # 
    query = ORIGIN_QUERY.rstrip('\n').split() + \
    map(lambda x: x[0], sorted([(t, new_vector[t]) for t in query if t not in ORIGIN_QUERY], \
                               key=lambda x: x[1], reverse=True))

    return query

# %%
def regularize(string):
    '''
    Discard all punctuations and stopwords, 
    convert all letters to lower case.
    '''
    return [word for word in re.sub(r'[^a-zA-Z0-9_ ]', '', string).lower().strip().split()\
            if word not in STOPWORDS]

# %%
def get_stopwords():
    '''
    Get a set of stopwords.
    '''
    with open('./proj1-stop.txt') as f:
        return set(word.rstrip('\n') for word in f.readlines())

# %%
def gen_default_input():
    '''
    Generate default input only for test purposes.
    '''
    SEARCH_ENGINE_ID = "018403154494399932789:5hcq8v_uic8"
    JSON_API_KEY = "AIzaSyA9gBRthSU9gOiOEtlLfN2NEAI4lxZQxTE"
    PREC = '0.9'
    ORIGIN_QUERY = 'per se'
    ORIGIN_QUERY = 'brin'
    ORIGIN_QUERY = 'columbia'
    return JSON_API_KEY, SEARCH_ENGINE_ID, PREC, ORIGIN_QUERY

# %%
def main():
    '''
    Main function.
    '''
    # Parse Arguments
    global JSON_API_KEY, SEARCH_ENGINE_ID, PREC, ORIGIN_QUERY, STOPWORDS
#     JSON_API_KEY, SEARCH_ENGINE_ID, PREC, origin_query = sys.argv[2], sys.argv[3], sys.argv[4], sys.argv[5]
    JSON_API_KEY, SEARCH_ENGINE_ID, PREC, ORIGIN_QUERY = gen_default_input()
    PREC = float(PREC)
    ORIGIN_QUERY = ORIGIN_QUERY.lower()  # Record original query terms
    STOPWORDS = get_stopwords()
    query = ORIGIN_QUERY.rstrip('\n').split()
    
    ### MAIN LOOP ###
    while True:
        query_result = search(query)
        if len(query_result) < 10:
            print "Not enough query results. Stop."
            return
        get_feedback(query_result, query)
        print "======================"
        print "FEEDBACK SUMMARY"
        print "Query {}".format(' '.join(query))
        prec = sum(q.is_relevant for q in query_result) / float(len(query_result))
        print "Precision {}".format(prec)
        if prec >= PREC:  # Reached goal, exit
            print "Desired precision reached, Done!"
            return
        elif prec == 0.0:  # Precision too low, exit
            print "Precision reached zero, stop."
            return
        print "Still below the desired precision of {}".format(PREC)
        query = modify_query(query_result, query)
    
    return

# %%
if __name__ == '__main__':
    main()
# Out:
# Parameters:
# Client Key = AIzaSyA9gBRthSU9gOiOEtlLfN2NEAI4lxZQxTE
# Engine Key = 018403154494399932789:5hcq8v_uic8
# Query = columbia
# Precision = 0.9
# Google Search Results:
# ======================
#
# Result #1:
# [
# URL: http://www.columbia.com/
#
# Title: Columbia Sportswear: Outdoor Clothing, Outerwear & Accessories
#
# Summary: Shop direct from Columbia Sportswear. Our Outerwear is Tested Tough in the
# Pacific NW. Shop for Jackets, Pants, Shirts, Shoes & more.
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #2:
# [
# URL: http://www.columbia.edu/
#
# Title: Columbia University in the City of New York
#
# Summary: ... Million Pledge from the Weinberg Foundation for Architectural Preservation
# Research at The Italian Academy · Read the latest issue of Columbia Magazine.
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #3:
# [
# URL: https://www.columbiasc.net/
#
# Title: Welcome to the City of Columbia
#
# Summary: Welcome to the official website of the City of Columbia! I hope that it is helpful to
# you, as we offer many services and attractions here in our beautiful capital city!
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #4:
# [
# URL: https://en.wikipedia.org/wiki/Columbia
#
# Title: Columbia - Wikipedia
#
# Summary: Columbia may refer to: Columbia (name), the female personification of the United
# States of America, and a poetic name for the Americas ...
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #5:
# [
# URL: http://www.columbiarecords.com/
#
# Title: Columbia Records | Music Moving Forward
#
# Summary: The Official Website of Columbia Records. ... COLUMBIA and the "Walking Eye"
# Design are registered trademarks of Sony Music Entertainment.Send Us ...
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #6:
# [
# URL: https://www.como.gov/
#
# Title: City of Columbia, Missouri's Official Government Web Site
#
# Summary: The City of Columbia Missouri's official web site. Perform business transactions,
# view services, department information, upcoming meetings and events.
#
# ]
#
# Relevant ([Y]/N)?
#
# Result #7:
# [
# URL: https://www8.gsb.columbia.edu/
#
# Title: Columbia Business School
#
# Summary: Columbia Business School is the Graduate Business School of Columbia
# University in New York City. Global perspective and cutting-edge methodology in
# an ...
#
# ]
#
# Relevant ([Y]/N)?
#
# Result #8:
# [
# URL: https://www.colum.edu/
#
# Title: Columbia College Chicago
#
# Summary: Site Map · Contact Us · Visit Us · Directory · About Columbia. © 2017 Columbia
# College Chicago; 600 S Michigan Ave, Chicago IL 60605 · Privacy · Consumer ...
#
# ]
#
# Relevant ([Y]/N)?
#
# Result #9:
# [
# URL: https://www.columbia.com/countries
#
# Title: Select Country & Language | Columbia Sportswear
#
# Summary: Please Select a Country and Language. Columbia Sportswear operates in North
# America, Europe, Asia, and more.
#
# ]
#
# Relevant ([Y]/N)?
#
# Result #10:
# [
# URL: https://twitter.com/columbia?lang=en
#
# Title: Columbia University (@Columbia) | Twitter
#
# Summary: 17.9K tweets • 1225 photos/videos • 241K followers. Check out the latest Tweets
# from Columbia University (@Columbia)
#
# ]
#
# Relevant ([Y]/N)?
# ======================
# FEEDBACK SUMMARY
# Query columbia
# Precision 0.5
# Still below the desired precision of 0.9
# Indexing results ...
# Indexing results ...
# [('business', 946.8492181853608),
#  ('school', 903.0899869919434),
#  ('chicago', 903.0899869919434),
#  ('tweets', 715.6818820794937),
#  ('college', 715.6818820794937),
#  ('language', 715.6818820794937),
#  ('country', 715.6818820794937),
#  ('select', 715.6818820794937),
#  ('missouris', 715.6818820794937),
#  ('university', 563.0974682310298),
#  ('meetings', 451.5449934959717),
#  ('global', 451.5449934959717),
#  ('179k', 451.5449934959717),
#  ('60605', 451.5449934959717),
#  ('241k', 451.5449934959717),
#  ('2017', 451.5449934959717),
#  ('government', 451.5449934959717),
#  ('michigan', 451.5449934959717),
#  ('twitter', 451.5449934959717),
#  ('operates', 451.5449934959717),
#  ('perspective', 451.5449934959717),
#  ('transactions', 451.5449934959717),
#  ('please', 451.5449934959717),
#  ('asia', 451.5449934959717),
#  ('europe', 451.5449934959717),
#  ('view', 451.5449934959717),
#  ('1225', 451.5449934959717),
#  ('privacy', 451.5449934959717),
#  ('visit', 451.5449934959717),
#  ('north', 451.5449934959717),
#  ('upcoming', 451.5449934959717),
#  ('600', 451.5449934959717),
#  ('ave', 451.5449934959717),
#  ('check', 451.5449934959717),
#  ('perform', 451.5449934959717),
#  ('graduate', 451.5449934959717),
#  ('methodology', 451.5449934959717),
#  ('contact', 451.5449934959717),
#  ('followers', 451.5449934959717),
#  ('department', 451.5449934959717),
#  ('events', 451.5449934959717),
#  ('map', 451.5449934959717),
#  ('cuttingedge', 451.5449934959717),
#  ('photosvideos', 451.5449934959717),
#  ('directory', 451.5449934959717),
#  ('consumer', 451.5449934959717),
#  ('sportswear', 400.19213457625096),
#  ('city', 356.6735818121748),
#  ('official', 279.7735326668794),
#  ('york', 252.49312484942953),
#  ('services', 252.49312484942953),
#  ('america', 252.49312484942953),
#  ('latest', 252.49312484942953),
#  ('shop', 0),
#  ('walking', 0),
#  ('outdoor', 0),
#  ('shoes', 0),
#  ('wikipedia', 0),
#  ('poetic', 0),
#  ('hope', 0),
#  ('outerwear', 0),
#  ('read', 0),
#  ('records', 0),
#  ('sony', 0),
#  ('name', 0),
#  ('helpful', 0),
#  ('refer', 0),
#  ('italian', 0),
#  ('pledge', 0),
#  ('direct', 0),
#  ('pacific', 0),
#  ('personification', 0),
#  ('research', 0),
#  ('capital', 0),
#  ('issue', 0),
#  ('pants', 0),
#  ('foundation', 0),
#  ('architectural', 0),
#  ('americas', 0),
#  ('magazine', 0),
#  ('tough', 0),
#  ('trademarks', 0),
#  ('attractions', 0),
#  ('preservation', 0),
#  ('jackets', 0),
#  ('eye', 0),
#  ('music', 0),
#  ('forward', 0),
#  ('offer', 0),
#  ('academy', 0),
#  ('registered', 0),
#  ('tested', 0),
#  ('design', 0),
#  ('shirts', 0),
#  ('beautiful', 0),
#  ('accessories', 0),
#  ('states', 0),
#  ('female', 0),
#  ('clothing', 0),
#  ('united', 0),
#  ('nw', 0),
#  ('weinberg', 0),
#  ('columbia', 0),
#  ('may', 0),
#  ('entertainmentsend', 0),
#  ('moving', 0)]
# Augmenting by business school
# Parameters:
# Client Key = AIzaSyA9gBRthSU9gOiOEtlLfN2NEAI4lxZQxTE
# Engine Key = 018403154494399932789:5hcq8v_uic8
# Query = columbia business school
# Precision = 0.9
# Google Search Results:
# ======================
#
# Result #1:
# [
# URL: https://www8.gsb.columbia.edu/
#
# Title: Columbia Business School
#
# Summary: Columbia Business School is the Graduate Business School of Columbia
# University in New York City. Global perspective and cutting-edge methodology in
# an ...
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #2:
# [
# URL: http://www8.gsb.columbia.edu/programs/mba
#
# Title: MBA Program | Programs
#
# Summary: Only Columbia Business School gives you the opportunity to shape your career
# in the very center of business. There's something about being positioned in New
#  ...
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #3:
# [
# URL: https://en.wikipedia.org/wiki/Columbia_Business_School
#
# Title: Columbia Business School - Wikipedia
#
# Summary: Columbia Business School (CBS) is the business school of Columbia University
# in Manhattan, New York City. It is one of six Ivy League business schools, and is
#  ...
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #4:
# [
# URL: http://www8.gsb.columbia.edu/programs/mba/admissions
#
# Title: MBA Admissions | Programs
#
# Summary: Columbia Business School uses a rolling admissions process, which means
# applications are reviewed — and decisions rendered — as they are received.
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #5:
# [
# URL: https://www.usnews.com/best-graduate-schools/top-business-schools/columbia-university-01148
#
# Title: Columbia University | Best Business School | US News
#
# Summary: Is Columbia University the best business school for you? Find out at US News.
# See if Columbia University is ranked and get info on programs, admission, tuition,
#  ...
#
# ]
#
# Relevant ([Y]/N)?n
#
# Result #6:
# [
# URL: http://www8.gsb.columbia.edu/programs/
#
# Title: Programs
#
# Summary: Centered in New York City, the global hub of business, Columbia Business
# School offers its diverse and entrepreneurial students daily access to influential ...
#
# ]
#
# Relevant ([Y]/N)?
#
# Result #7:
# [
# URL: https://www.facebook.com/columbiabusiness/
#
# Title: Columbia Business School - Home | Facebook
#
# Summary: Columbia Business School, New York, NY. 45299 likes · 353 talking about this ·
# 19156 were here. The Business School at Columbia University in NYC....
#
# ]
#
# Relevant ([Y]/N)?
#
# Result #8:
# [
# URL: https://www.youtube.com/user/ColumbiaBusiness
#
# Title: Columbia Business School - YouTube
#
# Summary: Columbia Business School is at the very center of business, pioneering practice
# and educating leaders through access to dynamic, real-world practitioners.
#
# ]
# Relevant ([Y]/N)?
#
# Result #9:
# [
# URL: https://www.forbes.com/colleges/columbia-university-in-the-city-of-new-york/columbia-business-school/
#
# Title: Columbia Business School
#
# Summary: One of the largest business schools in the country, Columbia Business School
# celebrated its centennial in 2015. Finance and Economics is the largest division ...
#
# ]
#
# Relevant ([Y]/N)?
#
# Result #10:
# [
# URL: https://www.linkedin.com/edu/columbia-business-school-18941
#
# Title: Columbia Business School | LinkedIn
#
# Summary: Columbia Business School is at the very center of business, pioneering practice
# and educating leaders through access to dynamic, real-world practitioners.
#
# ]
#
# Relevant ([Y]/N)?
# ======================
# FEEDBACK SUMMARY
# Query columbia business school
# Precision 0.5
# Still below the desired precision of 0.9
# Indexing results ...
# Indexing results ...
# [('largest', 715.6818820794937),
#  ('access', 708.3098389103757),
#  ('leaders', 631.2328121235738),
#  ('dynamic', 631.2328121235738),
#  ('educating', 631.2328121235738),
#  ('practitioners', 631.2328121235738),
#  ('pioneering', 631.2328121235738),
#  ('practice', 631.2328121235738),
#  ('realworld', 631.2328121235738),
#  ('linkedin', 451.5449934959717),
#  ('talking', 451.5449934959717),
#  ('diverse', 451.5449934959717),
#  ('likes', 451.5449934959717),
#  ('45299', 451.5449934959717),
#  ('hub', 451.5449934959717),
#  ('ny', 451.5449934959717),
#  ('celebrated', 451.5449934959717),
#  ('students', 451.5449934959717),
#  ('offers', 451.5449934959717),
#  ('2015', 451.5449934959717),
#  ('nyc', 451.5449934959717),
#  ('19156', 451.5449934959717),
#  ('division', 451.5449934959717),
#  ('finance', 451.5449934959717),
#  ('centered', 451.5449934959717),
#  ('facebook', 451.5449934959717),
#  ('influential', 451.5449934959717),
#  ('country', 451.5449934959717),
#  ('economics', 451.5449934959717),
#  ('youtube', 451.5449934959717),
#  ('daily', 451.5449934959717),
#  ('entrepreneurial', 451.5449934959717),
#  ('353', 451.5449934959717),
#  ('centennial', 451.5449934959717),
#  ('center', 424.9859033462254),
#  ('york', 287.50050980416347),
#  ('global', 252.49312484942953),
#  ('schools', 252.49312484942953),
#  ('city', 141.66196778207512),
#  ('programs', 71.87512745104087),
#  ('university', 35.937563725520434),
#  ('perspective', 0),
#  ('program', 0),
#  ('rendered', 0),
#  ('process', 0),
#  ('mba', 0),
#  ('reviewed', 0),
#  ('shape', 0),
#  ('rolling', 0),
#  ('decisions', 0),
#  ('ivy', 0),
#  ('best', 0),
#  ('admission', 0),
#  ('wikipedia', 0),
#  ('graduate', 0),
#  ('methodology', 0),
#  ('means', 0),
#  ('cbs', 0),
#  ('manhattan', 0),
#  ('gives', 0),
#  ('columbia', 0),
#  ('business', 0),
#  ('received', 0),
#  ('positioned', 0),
#  ('tuition', 0),
#  ('cuttingedge', 0),
#  ('applications', 0),
#  ('ranked', 0),
#  ('news', 0),
#  ('opportunity', 0),
#  ('info', 0),
#  ('league', 0),
#  ('school', 0),
#  ('see', 0),
#  ('admissions', 0),
#  ('career', 0),
#  ('uses', 0),
#  ('theres', 0)]
# Augmenting by largest access
# Parameters:
# Client Key = AIzaSyA9gBRthSU9gOiOEtlLfN2NEAI4lxZQxTE
# Engine Key = 018403154494399932789:5hcq8v_uic8
# Query = columbia largest access business school
# Precision = 0.9
# Google Search Results:
# ======================
#
# Result #1:
# [
# URL: http://www8.gsb.columbia.edu/about-us/why-columbia-business-school/access
#
# Title: Why Columbia Business School: Access
#
# Summary: Unmatched Exposure to the Pulse of Business. Speakers and Conferences. Our
# students not only have the opportunity to hear behind-the-scenes perspectives ...
#
# ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-2436fc2ab63a> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# <ipython-input-79-23eaecff79db> in main()
#      15     while True:
#      16         query_result = search(query)
# ---> 17         get_feedback(query_result, query)
#      18         print "======================"
#      19         print "FEEDBACK SUMMARY"
#
# <ipython-input-28-d5739823c45d> in get_feedback(query_result, query)
#      19         print "]\n"
#      20         # Receive user's feedback
# ---> 21         feedback = raw_input("Relevant ([Y]/N)?")
#      22         assert(feedback == '' or feedback.lower() in 'yn')
#      23         if feedback == '' or feedback.lower() == 'y':
#
# /Users/pengguo/anaconda/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /Users/pengguo/anaconda/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
'sdR34234\&^&*^(&*v\df\n'.lower()
# Out:
# 'sdr34234\\&^&*^(&*v\\df\n'

# %%
a = defaultdict(float)
print a['ss'] + 1
# Out:
# 1.0

# %%
'ss' in a
# Out:
# True
